# %% [markdown]
# <a href="https://colab.research.google.com/github/PrabodhMahajan/RuleBasedSentimentAnalysis/blob/master/TwitterSentimentAnalysis(RuleBased).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tweepy
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import pandas as pd

# %%
consumer_key = '75MzzfFKhOLsCK9O3OAKsEUhq'
consumer_secret = 'L36Bl3nJN3ZV5FkPjXLGsKqycaekhi2oo59DQ8zlGo0pijOz1W'
access_token ='1135519255439429632-0jqTGbWkA4nExs8BaIkYOJo8RImXG4'
access_token_secret = 'OBun9kbyxGqnqXAtxET5gCL5gFQ8SXR3SxMSm0GekB2F2'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
import re
def clean_tweet(tweet):
  return' '.join(re.sub("(@[A-Za-z0-9]+)| ([^0-9A-Za-z\t])|(\w+:\/\/\s+)"," ", tweet).split())

# %%
tweets = api.search('Apple watch', count = 200)
data = pd.DataFrame(data=[clean_tweet(tweet.text) for tweet in tweets],columns = ['Tweets'])
display(data.head(10))

print(tweets[0].id)
print(tweets[0].created_at)
print(tweets[0].source)
print(tweets[0].favorite_count)
print(tweets[0].retweet_count)
print(tweets[0].geo)
print(tweets[0].coordinates)
print(tweets[0].entities)
# Out:
#                                               Tweets
# 0  普通に歩いてたらApple Watchがひどく転倒されたようですとか言い出した。これわざと転...
# 1  Apple really likes their UI to be an easter eg...
# 2  RT BandTfans: Roswellians, do you want to see ...
# 3                しかしApple Watchと言う名の強敵に阻まれるのであった────
# 4  #WWDC19 RT TopDevelopersCo: Apple announced up...
# 5  The Apple Watch Is Now the Control Center for ...
# 6  RT jamesenglish0: my 2 hour podcast with tommy...
# 7  Voici tous les nouveaux cadrans de watchOS 6 h...
# 8  RT kings_____man: GIVEAWAY 🎁: APPLE WATCH x NI...
# 9  Came across this beautiful song while watching...
# 1136208180394860544
# 2019-06-05 09:48:34
# Tweetbot for iΟS
# 0
# 0
# None
# None
# {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
sid = SentimentIntensityAnalyzer()
list = []
for index, row in data.iterrows():
  ss = sid.polarity_scores(row["Tweets"])
  list.append(ss)
se = pd.Series(list)
data['polarity'] = se.values

# %%
display(data.head(100))
# Out:
#                                                Tweets                                           polarity
# 0   普通に歩いてたらApple Watchがひどく転倒されたようですとか言い出した。これわざと転...  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1   Apple really likes their UI to be an easter eg...  {'neg': 0.0, 'neu': 0.829, 'pos': 0.171, 'comp...
# 2   RT BandTfans: Roswellians, do you want to see ...  {'neg': 0.0, 'neu': 0.815, 'pos': 0.185, 'comp...
# 3                 しかしApple Watchと言う名の強敵に阻まれるのであった────  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4   #WWDC19 RT TopDevelopersCo: Apple announced up...  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 5   The Apple Watch Is Now the Control Center for ...  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 6   RT jamesenglish0: my 2 hour podcast with tommy...  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 7   Voici tous les nouveaux cadrans de watchOS 6 h...  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# ...
